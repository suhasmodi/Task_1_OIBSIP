# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Iris.csv")

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
ohe=OneHotEncoder()
label_encoder=LabelEncoder()

# df_encoded = pd.get_dummies(data, columns=['Species'])
data['category_column_encoded'] = label_encoder.fit_transform(data['Species'])
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    category_column_encoded
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data['category_column_encoded'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: category_column_encoded, dtype: int64

# %%
data.sample()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
#
#             Species  category_column_encoded
# 140  Iris-virginica                        2

# %%
y=data['category_column_encoded']
x=data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,train_size=0.8, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

models=[DecisionTreeClassifier(),LogisticRegression(),RandomForestClassifier()]

for model in models:
  model.fit(x_train,y_train)
  y_pred=model.predict(x_test)
  print("model: ",model)
  print("accuracy_score:",accuracy_score(y_test,y_pred))
# Out:
# model:  DecisionTreeClassifier()
# accuracy_score: 1.0
# model:  LogisticRegression()
# accuracy_score: 1.0
# model:  RandomForestClassifier()
# accuracy_score: 1.0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print("acc: ",accuracy_score(y_test,y_pred))
# Out:
# acc:  1.0

# %%
x_test.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 73             6.1           2.8            4.7           1.2
# 18             5.7           3.8            1.7           0.3
# 118            7.7           2.6            6.9           2.3
# 78             6.0           2.9            4.5           1.5
# 76             6.8           2.8            4.8           1.4

# %%
data2=pd.DataFrame({'SepalLengthCm':[5.6],'SepalWidthCm':[2.9],'PetalLengthCm':[4.2],'PetalWidthCm':[1.3]})

# %%
y_new_pred=model.predict(data2)
if(y_new_pred==0):
  print("Iris sentos")
elif (y_new_pred==1):
  print("Iris Virsicolor")
elif(y_new_pred==2):
  print("Iris Virginica")
else:
  print()
# Out:
# Iris Virsicolor

# %%
import pickle

# %%
pickle.dump(model, open('model.pkl', 'wb'))
